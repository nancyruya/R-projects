# %% [markdown]
# # Home-based Care Project

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/ruyazhang/Downloads/Medicare_Provider_Util_Payment_PUF_CY2018.txt', delimiter = "\t", skiprows = [1], low_memory=False)

# %%
df.head(3)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0               NaN              M.D.                     M                 I
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  ...  \
# 0           900 SETON DR                    NaN          CUMBERLAND  ...
# 1           900 SETON DR                    NaN          CUMBERLAND  ...
# 2           900 SETON DR                    NaN          CUMBERLAND  ...
#
#   hcpcs_code                                hcpcs_description  \
# 0      99217    Hospital observation care on day of discharge
# 1      99218  Hospital observation care, typically 30 minutes
# 2      99220  Hospital observation care, typically 70 minutes
#
#   hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 0                    N          68.0              67                68
# 1                    N          19.0              19                19
# 2                    N          26.0              26                26
#
#   average_Medicare_allowed_amt average_submitted_chrg_amt  \
# 0                    73.821029                 381.308824
# 1                   100.883158                 476.947368
# 2                   188.110769                1086.923077
#
#   average_Medicare_payment_amt  average_Medicare_standard_amt
# 0                    57.880294                      58.212500
# 1                    76.795263                      77.469474
# 2                   147.479231                     147.793462
#
# [3 rows x 26 columns]

# %%
df.set_index('hcpcs_code', inplace=True)
df.head()
# Out:
#                    npi nppes_provider_last_org_name nppes_provider_first_name  \
# hcpcs_code
# 99217       1003000126                    ENKESHAFI                   ARDALAN
# 99218       1003000126                    ENKESHAFI                   ARDALAN
# 99220       1003000126                    ENKESHAFI                   ARDALAN
# 99221       1003000126                    ENKESHAFI                   ARDALAN
# 99222       1003000126                    ENKESHAFI                   ARDALAN
#
#            nppes_provider_mi nppes_credentials nppes_provider_gender  \
# hcpcs_code
# 99217                    NaN              M.D.                     M
# 99218                    NaN              M.D.                     M
# 99220                    NaN              M.D.                     M
# 99221                    NaN              M.D.                     M
# 99222                    NaN              M.D.                     M
#
#            nppes_entity_code nppes_provider_street1 nppes_provider_street2  \
# hcpcs_code
# 99217                      I           900 SETON DR                    NaN
# 99218                      I           900 SETON DR                    NaN
# 99220                      I           900 SETON DR                    NaN
# 99221                      I           900 SETON DR                    NaN
# 99222                      I           900 SETON DR                    NaN
#
#            nppes_provider_city  ... place_of_service  \
# hcpcs_code                      ...
# 99217               CUMBERLAND  ...                F
# 99218               CUMBERLAND  ...                F
# 99220               CUMBERLAND  ...                F
# 99221               CUMBERLAND  ...                F
# 99222               CUMBERLAND  ...                F
#
#                                             hcpcs_description  \
# hcpcs_code
# 99217           Hospital observation care on day of discharge
# 99218         Hospital observation care, typically 30 minutes
# 99220         Hospital observation care, typically 70 minutes
# 99221       Initial hospital inpatient care, typically 30 ...
# 99222       Initial hospital inpatient care, typically 50 ...
#
#            hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt  \
# hcpcs_code
# 99217                         N          68.0              67
# 99218                         N          19.0              19
# 99220                         N          26.0              26
# 99221                         N          24.0              24
# 99222                         N          17.0              17
#
#            bene_day_srvc_cnt average_Medicare_allowed_amt  \
# hcpcs_code
# 99217                     68                    73.821029
# 99218                     19                   100.883158
# 99220                     26                   188.110769
# 99221                     24                   102.240000
# 99222                     17                   138.045882
#
#            average_submitted_chrg_amt  average_Medicare_payment_amt  \
# hcpcs_code
# 99217                      381.308824                     57.880294
# 99218                      476.947368                     76.795263
# 99220                     1086.923077                    147.479231
# 99221                      474.583333                     80.155000
# 99222                      625.000000                    108.225294
#
#             average_Medicare_standard_amt
# hcpcs_code
# 99217                           58.212500
# 99218                           77.469474
# 99220                          147.793462
# 99221                           80.943333
# 99222                          109.220000
#
# [5 rows x 25 columns]

# %% [markdown]
# ,"G0151","G0152","G0153","G0155","G0156","G0157","G0158","G0159","G0160","G0161","G0162","G0299","G0300","G0493","G0494","G0495","G0496","G2168","G2169","Q5001","Q5002","Q5009"
# df.loc["S0390"]

# %%
# df.loc[['90849', '90865']]

# %%
nd = df.loc[["99341","99342","99343","99344","99345","99347","99348","99349","99350","99324","99325","99326","99327","99328","99334","99335","99336","99337"]]
nd
# Out:
#                    npi nppes_provider_last_org_name nppes_provider_first_name  \
# hcpcs_code
# 99341       1003056821                 PIZZO-BERKEY                   ALLYSON
# 99341       1003813726                        BURNS                    ROBERT
# 99341       1003908898                       HOLMES                      EDNA
# 99341       1013265495                       GILROY                    ANDREA
# 99341       1013941582                     OSHEROFF                    ROBERT
# ...                ...                          ...                       ...
# 99337       1992904718                      ANGLADE                     MOISE
# 99337       1992921977                      REXROTH                   ROBERTA
# 99337       1992925671                     GONZALEZ                 JOSE NOEL
# 99337       1992955363                     GALLEGOS                    DANIEL
# 99337       1992982052                        ABNEY                     JASON
#
#            nppes_provider_mi nppes_credentials nppes_provider_gender  \
# hcpcs_code
# 99341                      J                MD                     F
# 99341                      A            D.P.M.                     M
# 99341                      C               DPM                     F
# 99341                    NaN               DPM                     F
# 99341                    NaN               DPM                     M
# ...                      ...               ...                   ...
# 99337                      W                MD                     M
# 99337                      K              ARNP                     F
# 99337                      P              CFNP                     M
# 99337                    NaN               ANP                     M
# 99337                      R                DO                     M
#
#            nppes_entity_code          nppes_provider_street1  \
# hcpcs_code
# 99341                      I                 351 HOSPITAL RD
# 99341                      I              28000 ROLLCREST RD
# 99341                      I                1700 ROSEDALE CT
# 99341                      I  2511 OLD CORNWALLIS RD STE 200
# 99341                      I               6105 ADMIRALTY LN
# ...                      ...                             ...
# 99337                      I      4915 SOUTH CONGRESS AVENUE
# 99337                      I              4644 KEYSVILLE AVE
# 99337                      I          21170 ASHBY PONDS BLVD
# 99337                      I              10645 N TATUM BLVD
# 99337                      I                    8 FALKNER DR
#
#            nppes_provider_street2 nppes_provider_city  ... place_of_service  \
# hcpcs_code                                             ...
# 99341                   SUITE 305       NEWPORT BEACH  ...                O
# 99341                         NaN    FARMINGTON HILLS  ...                O
# 99341                         NaN          WOODBRIDGE  ...                O
# 99341                         NaN              DURHAM  ...                O
# 99341                         NaN         FOSTER CITY  ...                O
# ...                           ...                 ...  ...              ...
# 99337                     SUITE A          LAKE WORTH  ...                O
# 99337                         NaN         SPRING HILL  ...                O
# 99337                         NaN             ASHBURN  ...                O
# 99337                     200-152             PHOENIX  ...                O
# 99337                         NaN        LADERA RANCH  ...                O
#
#                                             hcpcs_description  \
# hcpcs_code
# 99341            New patient home visit, typically 20 minutes
# 99341            New patient home visit, typically 20 minutes
# 99341            New patient home visit, typically 20 minutes
# 99341            New patient home visit, typically 20 minutes
# 99341            New patient home visit, typically 20 minutes
# ...                                                       ...
# 99337       Established patient assisted living visit, typ...
# 99337       Established patient assisted living visit, typ...
# 99337       Established patient assisted living visit, typ...
# 99337       Established patient assisted living visit, typ...
# 99337       Established patient assisted living visit, typ...
#
#            hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt  \
# hcpcs_code
# 99341                         N        1150.0            1150
# 99341                         N          13.0              13
# 99341                         N          19.0              19
# 99341                         N          37.0              37
# 99341                         N          24.0              24
# ...                         ...           ...             ...
# 99337                         N          21.0              17
# 99337                         N          46.0              31
# 99337                         N          89.0              54
# 99337                         N          86.0              44
# 99337                         N         341.0             183
#
#            bene_day_srvc_cnt average_Medicare_allowed_amt  \
# hcpcs_code
# 99341                   1150                    58.510000
# 99341                     13                    54.649231
# 99341                     19                    54.220000
# 99341                     37                    52.755946
# 99341                     24                    59.480000
# ...                      ...                          ...
# 99337                     21                   200.122857
# 99337                     46                   164.240000
# 99337                     89                   165.940674
# 99337                     86                   164.623256
# 99337                    341                   207.117947
#
#            average_submitted_chrg_amt  average_Medicare_payment_amt  \
# hcpcs_code
# 99341                       65.652174                     41.087443
# 99341                       85.000000                     18.436923
# 99341                       75.000000                     30.986316
# 99341                       53.816486                     36.956216
# 99341                      165.416667                     40.390000
# ...                               ...                           ...
# 99337                      219.285714                    156.894286
# 99337                      205.000000                    114.967391
# 99337                      223.090562                    102.158539
# 99337                      194.000000                     88.600698
# 99337                      438.149091                    154.710909
#
#             average_Medicare_standard_amt
# hcpcs_code
# 99341                           39.634078
# 99341                           19.642308
# 99341                           32.617368
# 99341                           40.149189
# 99341                           39.988333
# ...                                   ...
# 99337                          154.632857
# 99337                          118.270435
# 99337                          103.258764
# 99337                           90.797558
# 99337                          147.324751
#
# [44401 rows x 25 columns]

# %%
# df.loc["S0390"]
# df.loc["G0151"]

# %%
nd.reset_index(inplace=True)
nd
# Out:
#       hcpcs_code         npi nppes_provider_last_org_name  \
# 0          99341  1003056821                 PIZZO-BERKEY
# 1          99341  1003813726                        BURNS
# 2          99341  1003908898                       HOLMES
# 3          99341  1013265495                       GILROY
# 4          99341  1013941582                     OSHEROFF
# ...          ...         ...                          ...
# 44396      99337  1992904718                      ANGLADE
# 44397      99337  1992921977                      REXROTH
# 44398      99337  1992925671                     GONZALEZ
# 44399      99337  1992955363                     GALLEGOS
# 44400      99337  1992982052                        ABNEY
#
#       nppes_provider_first_name nppes_provider_mi nppes_credentials  \
# 0                       ALLYSON                 J                MD
# 1                        ROBERT                 A            D.P.M.
# 2                          EDNA                 C               DPM
# 3                        ANDREA               NaN               DPM
# 4                        ROBERT               NaN               DPM
# ...                         ...               ...               ...
# 44396                     MOISE                 W                MD
# 44397                   ROBERTA                 K              ARNP
# 44398                 JOSE NOEL                 P              CFNP
# 44399                    DANIEL               NaN               ANP
# 44400                     JASON                 R                DO
#
#       nppes_provider_gender nppes_entity_code          nppes_provider_street1  \
# 0                         F                 I                 351 HOSPITAL RD
# 1                         M                 I              28000 ROLLCREST RD
# 2                         F                 I                1700 ROSEDALE CT
# 3                         F                 I  2511 OLD CORNWALLIS RD STE 200
# 4                         M                 I               6105 ADMIRALTY LN
# ...                     ...               ...                             ...
# 44396                     M                 I      4915 SOUTH CONGRESS AVENUE
# 44397                     F                 I              4644 KEYSVILLE AVE
# 44398                     M                 I          21170 ASHBY PONDS BLVD
# 44399                     M                 I              10645 N TATUM BLVD
# 44400                     M                 I                    8 FALKNER DR
#
#       nppes_provider_street2  ... place_of_service  \
# 0                  SUITE 305  ...                O
# 1                        NaN  ...                O
# 2                        NaN  ...                O
# 3                        NaN  ...                O
# 4                        NaN  ...                O
# ...                      ...  ...              ...
# 44396                SUITE A  ...                O
# 44397                    NaN  ...                O
# 44398                    NaN  ...                O
# 44399                200-152  ...                O
# 44400                    NaN  ...                O
#
#                                        hcpcs_description hcpcs_drug_indicator  \
# 0           New patient home visit, typically 20 minutes                    N
# 1           New patient home visit, typically 20 minutes                    N
# 2           New patient home visit, typically 20 minutes                    N
# 3           New patient home visit, typically 20 minutes                    N
# 4           New patient home visit, typically 20 minutes                    N
# ...                                                  ...                  ...
# 44396  Established patient assisted living visit, typ...                    N
# 44397  Established patient assisted living visit, typ...                    N
# 44398  Established patient assisted living visit, typ...                    N
# 44399  Established patient assisted living visit, typ...                    N
# 44400  Established patient assisted living visit, typ...                    N
#
#       line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 0            1150.0            1150              1150
# 1              13.0              13                13
# 2              19.0              19                19
# 3              37.0              37                37
# 4              24.0              24                24
# ...             ...             ...               ...
# 44396          21.0              17                21
# 44397          46.0              31                46
# 44398          89.0              54                89
# 44399          86.0              44                86
# 44400         341.0             183               341
#
#       average_Medicare_allowed_amt average_submitted_chrg_amt  \
# 0                        58.510000                  65.652174
# 1                        54.649231                  85.000000
# 2                        54.220000                  75.000000
# 3                        52.755946                  53.816486
# 4                        59.480000                 165.416667
# ...                            ...                        ...
# 44396                   200.122857                 219.285714
# 44397                   164.240000                 205.000000
# 44398                   165.940674                 223.090562
# 44399                   164.623256                 194.000000
# 44400                   207.117947                 438.149091
#
#       average_Medicare_payment_amt  average_Medicare_standard_amt
# 0                        41.087443                      39.634078
# 1                        18.436923                      19.642308
# 2                        30.986316                      32.617368
# 3                        36.956216                      40.149189
# 4                        40.390000                      39.988333
# ...                            ...                            ...
# 44396                   156.894286                     154.632857
# 44397                   114.967391                     118.270435
# 44398                   102.158539                     103.258764
# 44399                    88.600698                      90.797558
# 44400                   154.710909                     147.324751
#
# [44401 rows x 26 columns]

# %%
mid = nd['hcpcs_code']
nd.drop(columns=['hcpcs_code'], axis=1, inplace=True)
nd.insert(16, 'hcpcs_code', mid)
nd
# Out:
#               npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0      1003056821                 PIZZO-BERKEY                   ALLYSON
# 1      1003813726                        BURNS                    ROBERT
# 2      1003908898                       HOLMES                      EDNA
# 3      1013265495                       GILROY                    ANDREA
# 4      1013941582                     OSHEROFF                    ROBERT
# ...           ...                          ...                       ...
# 44396  1992904718                      ANGLADE                     MOISE
# 44397  1992921977                      REXROTH                   ROBERTA
# 44398  1992925671                     GONZALEZ                 JOSE NOEL
# 44399  1992955363                     GALLEGOS                    DANIEL
# 44400  1992982052                        ABNEY                     JASON
#
#       nppes_provider_mi nppes_credentials nppes_provider_gender  \
# 0                     J                MD                     F
# 1                     A            D.P.M.                     M
# 2                     C               DPM                     F
# 3                   NaN               DPM                     F
# 4                   NaN               DPM                     M
# ...                 ...               ...                   ...
# 44396                 W                MD                     M
# 44397                 K              ARNP                     F
# 44398                 P              CFNP                     M
# 44399               NaN               ANP                     M
# 44400                 R                DO                     M
#
#       nppes_entity_code          nppes_provider_street1  \
# 0                     I                 351 HOSPITAL RD
# 1                     I              28000 ROLLCREST RD
# 2                     I                1700 ROSEDALE CT
# 3                     I  2511 OLD CORNWALLIS RD STE 200
# 4                     I               6105 ADMIRALTY LN
# ...                 ...                             ...
# 44396                 I      4915 SOUTH CONGRESS AVENUE
# 44397                 I              4644 KEYSVILLE AVE
# 44398                 I          21170 ASHBY PONDS BLVD
# 44399                 I              10645 N TATUM BLVD
# 44400                 I                    8 FALKNER DR
#
#       nppes_provider_street2 nppes_provider_city  ... hcpcs_code  \
# 0                  SUITE 305       NEWPORT BEACH  ...      99341
# 1                        NaN    FARMINGTON HILLS  ...      99341
# 2                        NaN          WOODBRIDGE  ...      99341
# 3                        NaN              DURHAM  ...      99341
# 4                        NaN         FOSTER CITY  ...      99341
# ...                      ...                 ...  ...        ...
# 44396                SUITE A          LAKE WORTH  ...      99337
# 44397                    NaN         SPRING HILL  ...      99337
# 44398                    NaN             ASHBURN  ...      99337
# 44399                200-152             PHOENIX  ...      99337
# 44400                    NaN        LADERA RANCH  ...      99337
#
#                                        hcpcs_description hcpcs_drug_indicator  \
# 0           New patient home visit, typically 20 minutes                    N
# 1           New patient home visit, typically 20 minutes                    N
# 2           New patient home visit, typically 20 minutes                    N
# 3           New patient home visit, typically 20 minutes                    N
# 4           New patient home visit, typically 20 minutes                    N
# ...                                                  ...                  ...
# 44396  Established patient assisted living visit, typ...                    N
# 44397  Established patient assisted living visit, typ...                    N
# 44398  Established patient assisted living visit, typ...                    N
# 44399  Established patient assisted living visit, typ...                    N
# 44400  Established patient assisted living visit, typ...                    N
#
#       line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 0            1150.0            1150              1150
# 1              13.0              13                13
# 2              19.0              19                19
# 3              37.0              37                37
# 4              24.0              24                24
# ...             ...             ...               ...
# 44396          21.0              17                21
# 44397          46.0              31                46
# 44398          89.0              54                89
# 44399          86.0              44                86
# 44400         341.0             183               341
#
#       average_Medicare_allowed_amt average_submitted_chrg_amt  \
# 0                        58.510000                  65.652174
# 1                        54.649231                  85.000000
# 2                        54.220000                  75.000000
# 3                        52.755946                  53.816486
# 4                        59.480000                 165.416667
# ...                            ...                        ...
# 44396                   200.122857                 219.285714
# 44397                   164.240000                 205.000000
# 44398                   165.940674                 223.090562
# 44399                   164.623256                 194.000000
# 44400                   207.117947                 438.149091
#
#       average_Medicare_payment_amt  average_Medicare_standard_amt
# 0                        41.087443                      39.634078
# 1                        18.436923                      19.642308
# 2                        30.986316                      32.617368
# 3                        36.956216                      40.149189
# 4                        40.390000                      39.988333
# ...                            ...                            ...
# 44396                   156.894286                     154.632857
# 44397                   114.967391                     118.270435
# 44398                   102.158539                     103.258764
# 44399                    88.600698                      90.797558
# 44400                   154.710909                     147.324751
#
# [44401 rows x 26 columns]

# %%
nd.to_csv("homebase.csv")
